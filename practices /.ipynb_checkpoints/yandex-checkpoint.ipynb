# %%
# =============================================================================================

# Дана матрица высот NxM, состоящая из положительных чисел. 
# Изначально Боб находится в верхней левой клетке и у него есть лестница длины K.
# Он может ходить в 4 соседние клетки (вверх, вниз, влево, вправо), если разница высот между ними не больше, чем K.

"""
5 7 0
2 9 0
6 8 8
"""


# при K = 1 пути нет
# при K = 2 есть единственный путь 5 -> 7 -> 9 -> 8 -> 8

"""
5 7 0
4 9 0 -> true
8 8 8
"""

"""
5 7 0
4 10 0 -> false
8 8 8
"""

"""
5 7 0
6 6 0 -> true 
8 8 8
"""

# Может ли Боб добраться до правой нижней клетки?

import numpy as np

i, j  = 0, 0
support_dict = dict()

def bob_can_reach(array, k, i, j):
    pairs = [(i-1, j), (i+1, j), (i, j-1), (i, j+1)]


    for n in pairs:
        if n[0] < 0 or n[1] < 0 or n[0] > array.shape[0]-1 or n[1] > array.shape[1]-1:
            continue 
            
        diff = array[i,j] - array[n[0], n[1]] 

        if diff <= k:
            i, j = n[0], n[1]





    # if i == array.shape[0]-1 and j == array.shape[1]-1:
    #     return True

    # l, r, u, b =  (i-1, j), (i+1, j), (i, j-1), (i, j+1)
    # l_dif, r_dif, b_dif, u_dif = abs(array[i,j] - l), abs(array[i,j] - r), abs(array[i,j] - b), abs(array[i,j] - u)

    # if l_dif <= k:
    #     i, j = l[0], l[1]
    #     bob_can_reach(array, k, i, j)

    # elif r_dif <= k:
    #     i, j = r[0], r[1]
    #     bob_can_reach(array, k, i, j)
    
    # elif b_dif <= k:
    #     i, j = b[0], b[1]
    #     bob_can_reach(array, k, i, j)
    
    # else:
    #     i, j = u[0], u[1]
    #     bob_can_reach(array, k, i, j)


    # array = [l if l_dif <= k, r if r_dif <= k, b if b_dif <= k, u if u_dif <= k]
